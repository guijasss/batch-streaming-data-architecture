# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu = 25
sigma = 3
s = [round(x) for x in np.random.normal(mu, sigma, 1000)]

# %%
s
# Out:
# [28,
#  31,
#  25,
#  21,
#  29,
#  27,
#  24,
#  24,
#  32,
#  27,
#  27,
#  26,
#  22,
#  30,
#  21,
#  27,
#  24,
#  29,
#  26,
#  25,
#  25,
#  27,
#  24,
#  27,
#  22,
#  20,
#  27,
#  29,
#  24,
#  28,
#  24,
#  20,
#  22,
#  26,
#  33,
#  23,
#  28,
#  32,
#  27,
#  24,
#  26,
#  25,
#  25,
#  20,
#  29,
#  22,
#  25,
#  25,
#  22,
#  21,
#  21,
#  25,
#  25,
#  28,
#  26,
#  31,
#  23,
#  29,
#  28,
#  28,
#  20,
#  22,
#  19,
#  31,
#  25,
#  24,
#  27,
#  22,
#  24,
#  24,
#  27,
#  19,
#  23,
#  23,
#  23,
#  23,
#  21,
#  23,
#  25,
#  27,
#  26,
#  23,
#  27,
#  27,
#  24,
#  23,
#  22,
#  27,
#  23,
#  21,
#  19,
#  27,
#  24,
#  29,
#  30,
#  25,
#  28,
#  28,
#  23,
#  29,
#  24,
#  24,
#  25,
#  30,
#  25,
#  26,
#  24,
#  25,
#  25,
#  27,
#  29,
#  29,
#  21,
#  19,
#  31,
#  26,
#  21,
#  23,
#  24,
#  26,
#  21,
#  25,
#  26,
#  24,
#  29,
#  22,
#  25,
#  25,
#  22,
#  24,
#  20,
#  19,
#  24,
#  20,
#  25,
#  18,
#  28,
#  20,
#  24,
#  26,
#  33,
#  22,
# ...
